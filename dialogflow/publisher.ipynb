# %% [markdown]
# # InDiE DialogFlow publisher POC
#
# InDiE (Intent Discovery Engine) is a module that builds a tree of intents using supplied SQL queries and corresponding utterances. It also provides fulfillment logic to convert intent and slot values into a SQL query.
#
# ## DialogFlow publisher
# The DialogFlow (DF) publisher module takes the list of intents from a simplified InDiE json file. It uses DialogFlow APIs to create corresponding intents in a DialogFlow agent. It also configures DF agent to ask the user for any missing slots. Custom entities are also published so DF can detect particular types of entities from user utterance.

# %%
# %load_ext autoreload
# %autoreload 1

# !mkdir indie_df_publisher

# %%
# %%writefile indie_df_publisher/dialogflow_agent.py
import dialogflow_v2 as dialogflow

class DialogFlowAgent:
    def __init__(self, namespace, project):
        self.namespace = namespace
        self.project = project
        self.agents_client = dialogflow.AgentsClient()
        self.intents_client = dialogflow.IntentsClient()

        self.agent = self.load_agent()

    def load_agent(self):
        parent = self.agents_client.project_path(self.project)
        agent = self.agents_client.get_agent(parent)
        return agent

    def set_default_agent(self):
        parent = self.agents_client.project_path(self.project)

        a2 = dialogflow.types.Agent()
        a2.parent = parent
        a2.display_name = f"{self.namespace} agent"
        a2.default_language_code = "en"
        a2.time_zone = "America/Denver"
        a2.classification_threshold = 0.3
        self.agent = agents_client.set_agent(a2)
        return self.agent
    
    def list_intents(self):
        parent = self.intents_client.project_agent_path(self.project)
        return {x.display_name:x for x in self.intents_client.list_intents(parent)}

    def delete_indie_intents(self):
        parent = self.intents_client.project_agent_path(self.project)

        intents = self.list_intents()
        intents_to_delete = []
        for display_name in intents:
            if display_name.startswith(self.namespace):
                intents_to_delete.append(intents[display_name])
        if len(intents_to_delete) > 0:
            self.intents_client.batch_delete_intents(parent, intents_to_delete)
        
    def build_intent(self, display_name_suffix, training_phrases=None,
                      message_texts=None, parameters=None, is_fallback=False,
                      parent_followup_intent_name=None):
        parent = self.intents_client.project_agent_path(self.project)

        messages = []
        if message_texts:
            text = dialogflow.types.Intent.Message.Text(text=message_texts)
            message = dialogflow.types.Intent.Message(text=text)
            messages.append(message)

        intent = dialogflow.types.Intent(
            display_name=f"{self.namespace}_{display_name_suffix}",
            training_phrases=training_phrases,
            messages=messages,
            parameters=parameters,
            is_fallback=is_fallback,
            parent_followup_intent_name=parent_followup_intent_name)
        
        intent.webhook_state = dialogflow.types.Intent.WebhookState.WEBHOOK_STATE_ENABLED

        return intent

    def create_intents(self, intents):
        parent = self.intents_client.project_agent_path(self.project)

        intents_batch =  dialogflow.types.IntentBatch()
        intents_batch.intents.extend(intents)
        response = self.intents_client.batch_update_intents(parent, intent_batch_inline=intents_batch)

        def callback(operation_future):
            # Handle result.
            result = operation_future.result()
            print('Intents created:')
            print(result)

        response.add_done_callback(callback)
        
    def train(self):
        parent = self.agents_client.project_path(self.project)

        response = self.agents_client.train_agent(parent)
        def callback(operation_future):
            # Handle result.
            result = operation_future.result()
            print('Agent training:')
            print(result)

        response.add_done_callback(callback)
# Out:
# Writing indie_df_publisher/dialogflow_agent.py

# %%
# %%writefile indie_df_publisher/entity_types_publisher.py
import dialogflow_v2 as dialogflow

class EntityTypesPublisher:
    def __init__(self, namespace, project):
        self.client = dialogflow.EntityTypesClient()
        self.project = project
        self.namespace = namespace
        self.table_column_to_custom_entity = {}

    def create_entity_types(self, indie_custom_entities, indie):
        parent = self.client.project_agent_path(self.project)

        entity_type_batch = dialogflow.types.EntityTypeBatch()
        for de in indie_custom_entities:
            et = self.indie_custom_entity_to_dialogflow_entity_type(de)
            if et:
                entity_type_batch.entity_types.append(et)

        response = self.client.batch_update_entity_types(parent, entity_type_batch_inline=entity_type_batch)

        def callback(operation_future):
            # Handle result.
            result = operation_future.result()
            print('Entity types created')
            print(result)

        response.add_done_callback(callback)
        
    def indie_custom_entity_to_dialogflow_entity_type(self, indie_custom_entity):
        entity_type = dialogflow.types.EntityType()
        entity_type.display_name = f"{self.namespace}-{indie_custom_entity['index']}"
        self.table_column_to_custom_entity[f"{indie_custom_entity['table']}.{indie_custom_entity['column']}"] = f"@{entity_type.display_name}"
        entity_type.kind = 1
        
        for value, synonyms in indie_custom_entity['dictionary'].items():
            entity = dialogflow.types.EntityType.Entity()
            entity.value = value
            if len(synonyms) > 0:
                entity.synonyms.extend(synonyms)
            entity_type.entities.append(entity)
        
        return entity_type

    def list_entity_types(self):
        parent = self.client.project_agent_path(self.project)
        return {x.display_name:x for x in self.client.list_entity_types(parent)}
    
    def delete_indie_entity_types(self):
        parent = self.client.project_agent_path(self.project)

        entity_types = self.list_entity_types()
        entity_types_to_delete = []
        for display_name in entity_types:
            if display_name.startswith(self.namespace):
                entity_types_to_delete.append(entity_types[display_name].name)
        if len(entity_types_to_delete) > 0:
            self.client.batch_delete_entity_types(parent, entity_types_to_delete)
# Out:
# Writing indie_df_publisher/entity_types_publisher.py

# %%
# %%writefile indie_df_publisher/dialogflow_publisher.py

from indie_df_publisher.dialogflow_agent import DialogFlowAgent
from indie_df_publisher.entity_types_publisher import EntityTypesPublisher

import dialogflow_v2 as dialogflow

class DialogFlowPublisher:
    def __init__(self, namespace, project):
        self.namespace = namespace
        self.dialogflow_agent = DialogFlowAgent(namespace, project)
        self.entity_types_publisher = EntityTypesPublisher(namespace, project)
    
    def indie_training_phrases_to_dialogflow_training_phrases(self, indie_training_phrases):
        return [self.indie_training_phrase_to_dialogflow_training_phrase(tp) for tp in indie_training_phrases]
        
    def indie_training_phrase_to_dialogflow_training_phrase(self, indie_training_phrase):
        tp = dialogflow.types.Intent.TrainingPhrase()
        for part in indie_training_phrase['parts']:
            tpp = dialogflow.types.Intent.TrainingPhrase.Part()
            tpp.text = part['text']
            
            if 'alias' in part:
                tpp.alias = part['alias']

            if 'entity_type' in part:
                tpp.entity_type = part['entity_type']

            tp.parts.append(tpp)

        return tp    

    def indie_intent_to_dialogflow_intent(self, indie_intent, indie):
        display_name_suffix = indie_intent['id']

        training_phrases = self.indie_training_phrases_to_dialogflow_training_phrases(indie_intent['utterances'])
        followup_training_phrases = self.indie_training_phrases_to_dialogflow_training_phrases(indie_intent['followup_utterances'])

        parameters = []
        for indie_parameter in indie_intent['parameters']:
            parameter = dialogflow.types.Intent.Parameter(
                display_name=indie_parameter['id'],
                value=f"${indie_parameter['id']}",
                is_list=True,
                mandatory=indie_parameter['mandatory'],
                entity_type_display_name=indie_parameter['entity_type'],
                prompts=[f"What {indie_parameter['friendly_name']}?"])
            parameters.append(parameter)
            
        message = indie_intent['response_template']
        
        main_intent = self.dialogflow_agent.build_intent(display_name_suffix=display_name_suffix,
                                                  training_phrases=training_phrases,
                                                  message_texts=[message],
                                                  parameters=parameters,
                                                  is_fallback=False)

        followup_intent = self.dialogflow_agent.build_intent(display_name_suffix=display_name_suffix + '_followup',
                                                  training_phrases=followup_training_phrases,
                                                  message_texts=[message],
                                                  parameters=parameters,
                                                  is_fallback=False,
                                                  parent_followup_intent_name=main_intent.display_name)

        return main_intent, followup_intent
        

    def publish(self, indie):
        self.dialogflow_agent.delete_indie_intents()
        
        self.entity_types_publisher.delete_indie_entity_types()
        self.entity_types_publisher.create_entity_types(indie['custom_entities'].values(), indie)

        df_intents = []
        df_followup_intents = []
        indie_intents = indie['intents']
        
        for indie_intent in indie_intents:
            main_intent, followup_intent = self.indie_intent_to_dialogflow_intent(indie_intent, indie)
            df_intents.append(main_intent)
            if followup_intent:
                df_followup_intents.append(followup_intent)

        self.dialogflow_agent.create_intents(df_intents)
        intents = self.dialogflow_agent.list_intents()
        
        for df_followup_intent in df_followup_intents:
            df_followup_intent.parent_followup_intent_name = intents[df_followup_intent.parent_followup_intent_name].name

        self.dialogflow_agent.create_intents(df_followup_intents)
        
        self.dialogflow_agent.train()
# Out:
# Overwriting indie_df_publisher/dialogflow_publisher.py

# %%
# %%writefile indie_df_publisher/publish.py

# %aimport indie_df_publisher.dialogflow_agent
# %aimport indie_df_publisher.entity_types_publisher
# %aimport indie_df_publisher.dialogflow_publisher

from indie_df_publisher.dialogflow_publisher import DialogFlowPublisher

import dialogflow_v2 as dialogflow # https://dialogflow-python-client-v2.readthedocs.io/en/latest/gapic/v2beta1/api.html
import json

class args: pass

# Configuration to access and modify a DialogFlow agent
# %env GOOGLE_APPLICATION_CREDENTIALS=/Users/amolk/work/gotit/tutoruniverse/dialogflow_publisher/k3-oekhkw-65c192c69f18.json
args.dialogflow_project = "k3-oekhkw"
args.simple_indie_format_file_path = "../data/InDiE_0.3_CCAI_20200608155202.simple.json"

publisher = DialogFlowPublisher(namespace='gotit', project=args.dialogflow_project)

with open(args.simple_indie_format_file_path) as json_file:
    simple_indie = json.load(json_file)

publisher.publish(simple_indie)
# Out:
# env: GOOGLE_APPLICATION_CREDENTIALS=/Users/amolk/work/gotit/tutoruniverse/dialogflow_publisher/k3-oekhkw-65c192c69f18.json
# Entity types created
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/74b5621c-75d3-4dcb-b544-c24a5d166baa"
#   display_name: "gotit-0"
#   kind: KIND_MAP
#   entities {
#     value: "online"
#     synonyms: "online"
#   }
#   entities {
#     value: "store"
#     synonyms: "store"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/cf6c7992-fe36-4437-88fe-83b22745d457"
#   display_name: "gotit-1"
#   kind: KIND_MAP
#   entities {
#     value: "10GB plan"
#     synonyms: "10GB plan"
#   }
#   entities {
#     value: "earphones"
#     synonyms: "earphones"
#   }
#   entities {
#     value: "family plan"
#     synonyms: "family plan"
#   }
#   entities {
#     value: "ipad"
#     synonyms: "ipad"
#   }
#   entities {
#     value: "ipad pro"
#     synonyms: "ipad pro"
#   }
#   entities {
#     value: "iphone 11"
#     synonyms: "iphone 11"
#   }
#   entities {
#     value: "iphone 11 pro"
#     synonyms: "iphone 11 pro"
#   }
#   entities {
#     value: "iphone 7"
#     synonyms: "iphone 7"
#   }
#   entities {
#     value: "iphone 8"
#     synonyms: "iphone 8"
#   }
#   entities {
#     value: "iphone XS"
#     synonyms: "iphone XS"
#   }
#   entities {
#     value: "iphone cover"
#     synonyms: "iphone cover"
#   }
#   entities {
#     value: "screen protector"
#     synonyms: "screen protector"
#   }
#   entities {
#     value: "unlimited plan"
#     synonyms: "unlimited plan"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/b1f73b71-60ed-4aa2-9151-7e03dbee77f7"
#   display_name: "gotit-2"
#   kind: KIND_MAP
#   entities {
#     value: "Email"
#     synonyms: "Email"
#   }
#   entities {
#     value: "SEM"
#     synonyms: "SEM"
#   }
#   entities {
#     value: "SEO"
#     synonyms: "SEO"
#   }
#   entities {
#     value: "SMS"
#     synonyms: "SMS"
#   }
#   entities {
#     value: "direct"
#     synonyms: "direct"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/e68b77f3-3c08-4b0a-83ce-4b3eec829663"
#   display_name: "gotit-3"
#   kind: KIND_MAP
#   entities {
#     value: "Friday"
#     synonyms: "Friday"
#   }
#   entities {
#     value: "Monday"
#     synonyms: "Monday"
#   }
#   entities {
#     value: "Saturday"
#     synonyms: "Saturday"
#   }
#   entities {
#     value: "Sunday"
#     synonyms: "Sunday"
#   }
#   entities {
#     value: "Thursday"
#     synonyms: "Thursday"
#   }
#   entities {
#     value: "Tuesday"
#     synonyms: "Tuesday"
#   }
#   entities {
#     value: "Wednesday"
#     synonyms: "Wednesday"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/37bdff9c-6cc3-486f-82e0-0d6374bfe521"
#   display_name: "gotit-4"
#   kind: KIND_MAP
#   entities {
#     value: "April"
#     synonyms: "April"
#   }
#   entities {
#     value: "August"
#     synonyms: "August"
#   }
#   entities {
#     value: "December"
#     synonyms: "December"
#   }
#   entities {
#     value: "February"
#     synonyms: "February"
#   }
#   entities {
#     value: "January"
#     synonyms: "January"
#   }
#   entities {
#     value: "July"
#     synonyms: "July"
#   }
#   entities {
#     value: "June"
#     synonyms: "June"
#   }
#   entities {
#     value: "March"
#     synonyms: "March"
#   }
#   entities {
#     value: "May"
#     synonyms: "May"
#   }
#   entities {
#     value: "November"
#     synonyms: "November"
#   }
#   entities {
#     value: "October"
#     synonyms: "October"
#   }
#   entities {
#     value: "September"
#     synonyms: "September"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/d64a746c-53a4-4dfb-bb55-2a64bd23e3bc"
#   display_name: "gotit-5"
#   kind: KIND_MAP
#   entities {
#     value: "10GB plan"
#     synonyms: "10GB"
#     synonyms: "10GB plan"
#   }
#   entities {
#     value: "earphones"
#     synonyms: "earphones"
#   }
#   entities {
#     value: "family plan"
#     synonyms: "family plan"
#   }
#   entities {
#     value: "ipad"
#     synonyms: "ipad"
#   }
#   entities {
#     value: "ipad pro"
#     synonyms: "ipad pro"
#   }
#   entities {
#     value: "iphone 11"
#     synonyms: "iphone 11"
#   }
#   entities {
#     value: "iphone 11 pro"
#     synonyms: "iphone 11 pro"
#   }
#   entities {
#     value: "iphone 7"
#     synonyms: "iphone 7"
#   }
#   entities {
#     value: "iphone 8"
#     synonyms: "iphone 8"
#   }
#   entities {
#     value: "iphone XS"
#     synonyms: "iphone XS"
#   }
#   entities {
#     value: "iphone cover"
#     synonyms: "iphone cover"
#   }
#   entities {
#     value: "screen protector"
#     synonyms: "screen protector"
#   }
#   entities {
#     value: "unlimited plan"
#     synonyms: "unlimited plan"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/a0c5f720-ecf5-411e-b8ec-32072dd3ae0e"
#   display_name: "gotit-6"
#   kind: KIND_MAP
#   entities {
#     value: "10GB plan"
#     synonyms: "10GB plan"
#   }
#   entities {
#     value: "earphones"
#     synonyms: "earphones"
#   }
#   entities {
#     value: "family plan"
#     synonyms: "family plan"
#   }
#   entities {
#     value: "ipad"
#     synonyms: "ipad"
#   }
#   entities {
#     value: "ipad pro"
#     synonyms: "ipad pro"
#   }
#   entities {
#     value: "iphone 11"
#     synonyms: "iphone 11"
#   }
#   entities {
#     value: "iphone 11 pro"
#     synonyms: "iphone 11 pro"
#   }
#   entities {
#     value: "iphone 7"
#     synonyms: "iphone 7"
#   }
#   entities {
#     value: "iphone 8"
#     synonyms: "iphone 8"
#   }
#   entities {
#     value: "iphone XS"
#     synonyms: "iphone XS"
#   }
#   entities {
#     value: "iphone cover"
#     synonyms: "iphone cover"
#   }
#   entities {
#     value: "screen protector"
#     synonyms: "screen protector"
#   }
#   entities {
#     value: "unlimited plan"
#     synonyms: "unlimited plan"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/e0495b00-a3e8-47c5-99a4-f67605e1f78b"
#   display_name: "gotit-7"
#   kind: KIND_MAP
#   entities {
#     value: "accessories"
#     synonyms: "accessories"
#   }
#   entities {
#     value: "bundled plans"
#     synonyms: "bundled plans"
#   }
#   entities {
#     value: "phone"
#     synonyms: "phone"
#   }
#   entities {
#     value: "tablets"
#     synonyms: "tablets"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/5e63b42e-be4e-42df-bcc4-f9d45bc59f4e"
#   display_name: "gotit-8"
#   kind: KIND_MAP
#   entities {
#     value: "devices"
#     synonyms: "devices"
#   }
#   entities {
#     value: "internet"
#     synonyms: "internet"
#   }
#   entities {
#     value: "voice plans"
#     synonyms: "voice plans"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/20e907f9-4a6a-4751-842c-e24e67c50105"
#   display_name: "gotit-9"
#   kind: KIND_MAP
#   entities {
#     value: "black"
#     synonyms: "black"
#   }
#   entities {
#     value: "gold"
#     synonyms: "gold"
#   }
#   entities {
#     value: "red"
#     synonyms: "red"
#   }
#   entities {
#     value: "silver"
#     synonyms: "silver"
#   }
#   entities {
#     value: "white"
#     synonyms: "white"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/d4d30dc4-9dc1-4d68-8ab1-59ed57707399"
#   display_name: "gotit-10"
#   kind: KIND_MAP
#   entities {
#     value: "Black Friday"
#     synonyms: "Black Friday"
#   }
#   entities {
#     value: "Christmas"
#     synonyms: "Christmas"
#   }
#   entities {
#     value: "July 4"
#     synonyms: "July 4"
#   }
#   entities {
#     value: "Semi-annual"
#     synonyms: "Semi-annual"
#   }
#   entities {
#     value: "Valentine"
#     synonyms: "Valentine"
#   }
#   entities {
#     value: "Weekend"
#     synonyms: "Weekend"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/994cf7bd-223e-4d2f-972c-620750380f0d"
#   display_name: "gotit-11"
#   kind: KIND_MAP
#   entities {
#     value: "buy_one_get_one"
#     synonyms: "buy_one_get_one"
#   }
#   entities {
#     value: "discount"
#     synonyms: "discount"
#   }
#   entities {
#     value: "multiples"
#     synonyms: "multiples"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/fd5b20ef-5257-4837-9c7f-9113462c9771"
#   display_name: "gotit-12"
#   kind: KIND_MAP
#   entities {
#     value: "billboard"
#     synonyms: "billboard"
#   }
#   entities {
#     value: "newspaper"
#     synonyms: "newspaper"
#   }
#   entities {
#     value: "pamphlet"
#     synonyms: "pamphlet"
#   }
#   entities {
#     value: "radio"
#     synonyms: "radio"
#   }
#   entities {
#     value: "tv"
#     synonyms: "tv"
#   }
#   entities {
#     value: "web"
#     synonyms: "web"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/513274fc-0717-49d1-853b-1cb490106f10"
#   display_name: "gotit-13"
#   kind: KIND_MAP
#   entities {
#     value: "ABC"
#     synonyms: "ABC"
#   }
#   entities {
#     value: "CBS"
#     synonyms: "CBS"
#   }
#   entities {
#     value: "Facebook"
#     synonyms: "Facebook"
#   }
#   entities {
#     value: "Google ads"
#     synonyms: "Google ads"
#   }
#   entities {
#     value: "HBO"
#     synonyms: "HBO"
#   }
#   entities {
#     value: "LA time"
#     synonyms: "LA time"
#   }
#   entities {
#     value: "NY times"
#     synonyms: "NY times"
#   }
#   entities {
#     value: "Radio 92.3"
#     synonyms: "Radio 92.3"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/89196ae0-0982-4668-a3ac-2f66bf9508e9"
#   display_name: "gotit-14"
#   kind: KIND_MAP
#   entities {
#     value: "Atlanta"
#     synonyms: "Atlanta"
#   }
#   entities {
#     value: "Boston"
#     synonyms: "Boston"
#   }
#   entities {
#     value: "Cambridge"
#     synonyms: "Cambridge"
#   }
#   entities {
#     value: "Chicago"
#     synonyms: "Chicago"
#   }
#   entities {
#     value: "Kansas"
#     synonyms: "Kansas"
#   }
#   entities {
#     value: "Las Vegas"
#     synonyms: "Las Vegas"
#   }
#   entities {
#     value: "Los Angeles"
#     synonyms: "Los Angeles"
#   }
#   entities {
#     value: "Miami"
#     synonyms: "Miami"
#   }
#   entities {
#     value: "New York City"
#     synonyms: "New York City"
#   }
#   entities {
#     value: "San Francisco"
#     synonyms: "San Francisco"
#   }
#   entities {
#     value: "Seattle"
#     synonyms: "Seattle"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/a1972b0e-9530-4cfd-b7a1-4275a88e1d11"
#   display_name: "gotit-15"
#   kind: KIND_MAP
#   entities {
#     value: "online"
#     synonyms: "online"
#   }
#   entities {
#     value: "physical"
#     synonyms: "physical"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/b45d299d-04cd-4388-b439-f2a8235dc9a5"
#   display_name: "gotit-16"
#   kind: KIND_MAP
#   entities {
#     value: "Midwest"
#     synonyms: "Midwest"
#   }
#   entities {
#     value: "Northeast"
#     synonyms: "Northeast"
#   }
#   entities {
#     value: "South"
#     synonyms: "South"
#   }
#   entities {
#     value: "West"
#     synonyms: "West"
#   }
# }
#
# Intents created:
# intents {
#   name: "projects/k3-oekhkw/agent/intents/78f7a0af-0c6b-4c00-976a-257a2771d6fc"
#   display_name: "gotit_rvlfqusz"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "5bfc51ca-956b-4205-ba13-d17be1121873"
#     display_name: "slot-9"
#     value: "$slot-9"
#     entity_type_display_name: "@sys.number"
#     mandatory: true
#     prompts: "What Order ID?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/88989a96-8b61-4cad-9495-7a87453ff47d"
#   display_name: "gotit_uahznbcl"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "845c2367-25e0-432a-8c7e-6a06eb3a2d91"
#     display_name: "slot-9"
#     value: "$slot-9"
#     entity_type_display_name: "@sys.number"
#     mandatory: true
#     prompts: "What Order ID?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1, $result-slot-2, $result-slot-3, $result-slot-4, $result-slot-5"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/5a9841ee-21b8-42b4-a3ba-f6847e5b0ed0"
#   display_name: "gotit_tureiyga"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "4eb78fee-9a7e-4ea7-bf80-880da16d41fb"
#     display_name: "slot-8"
#     value: "$slot-8"
#     entity_type_display_name: "@sys.email"
#     mandatory: true
#     prompts: "What Email?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/603bc34b-7a38-402c-a674-912d564e8c3c"
#   display_name: "gotit_dzlbcqek"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "05651501-8a81-48ef-9496-90b6136c4ba2"
#     display_name: "slot-6"
#     value: "$slot-6"
#     entity_type_display_name: "@sys.person"
#     mandatory: true
#     prompts: "What Customer Name?"
#     is_list: true
#   }
#   parameters {
#     name: "fe266308-4273-42aa-992c-2f9b61dd3805"
#     display_name: "slot-7"
#     value: "$slot-7"
#     entity_type_display_name: "@sys.number"
#     mandatory: true
#     prompts: "What InDiE.slot.generic0002?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1, $result-slot-2, $result-slot-3"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/e8db82e8-77f4-433a-a8bd-51ed7c44a7d7"
#   display_name: "gotit_zlfjkocp"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "ec0392ec-118c-4b85-9800-840092e8274f"
#     display_name: "slot-4"
#     value: "$slot-4"
#     entity_type_display_name: "@gotit-10"
#     mandatory: true
#     prompts: "What Promotion Name?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/a6f4ddef-82c5-4dfe-9b50-9b78324fe059"
#   display_name: "gotit_yrvqkgmw"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "1d1ed1b0-ee6b-493a-99c7-febf0b282af9"
#     display_name: "slot-3"
#     value: "$slot-3"
#     entity_type_display_name: "@sys.geo-city"
#     mandatory: true
#     prompts: "What City?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/e96af4ac-89b2-4ea7-b467-6e68c7614b3d"
#   display_name: "gotit_hubygliz"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "c1778bce-ea5b-4391-996e-db78e7dde42c"
#     display_name: "slot-3"
#     value: "$slot-3"
#     entity_type_display_name: "@sys.geo-city"
#     mandatory: true
#     prompts: "What City?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1, $result-slot-2"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/40b74f47-8e5d-4545-b4cb-9c67ed10edf0"
#   display_name: "gotit_edcuyjqa"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "d5b44f40-a807-4633-a6dd-4338e3439636"
#     display_name: "slot-1"
#     value: "$slot-1"
#     entity_type_display_name: "@gotit-5"
#     mandatory: true
#     prompts: "What Product Name?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/72670a67-1be8-439b-9ee3-5bb5b44e021f"
#   display_name: "gotit_wlyokmra"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "052a12da-aa1f-4070-8d92-0cd0f8fae9de"
#     display_name: "slot-1"
#     value: "$slot-1"
#     entity_type_display_name: "@gotit-5"
#     mandatory: true
#     prompts: "What Product Name?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/ee893cb1-ab02-4ce9-82e4-646dd1e79462"
#   display_name: "gotit_rltvuehd"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "da214840-cdf3-4f36-93f4-5aff23f44bef"
#     display_name: "slot-1"
#     value: "$slot-1"
#     entity_type_display_name: "@gotit-5"
#     mandatory: true
#     prompts: "What Product Name?"
#     is_list: true
#   }
#   parameters {
#     name: "b1bdb697-3f57-4906-9ee9-8202ba1a4dfb"
#     display_name: "slot-2"
#     value: "$slot-2"
#     entity_type_display_name: "@gotit-8"
#     mandatory: true
#     prompts: "What Product Category?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1, $result-slot-2, $result-slot-3, $result-slot-4, $result-slot-5"
#     }
#   }
# }
#
# Intents created:
# intents {
#   name: "projects/k3-oekhkw/agent/intents/fe5f6e9f-4cca-4bcc-91c1-7d6f3aa56191"
#   display_name: "gotit_rvlfqusz_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "84c95195-dafd-4659-8d4d-e5c903884dd8"
#     display_name: "slot-9"
#     value: "$slot-9"
#     entity_type_display_name: "@sys.number"
#     mandatory: true
#     prompts: "What Order ID?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/78f7a0af-0c6b-4c00-976a-257a2771d6fc"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/78f7a0af-0c6b-4c00-976a-257a2771d6fc"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/69061a8e-71d7-4cbf-a13d-e7d69181c06c"
#   display_name: "gotit_uahznbcl_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "8a40091b-28ca-4e58-b453-ba46c3954dc1"
#     display_name: "slot-9"
#     value: "$slot-9"
#     entity_type_display_name: "@sys.number"
#     mandatory: true
#     prompts: "What Order ID?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1, $result-slot-2, $result-slot-3, $result-slot-4, $result-slot-5"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/88989a96-8b61-4cad-9495-7a87453ff47d"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/88989a96-8b61-4cad-9495-7a87453ff47d"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/2316a891-cf45-4f76-9d0d-ef4a1c2b99b3"
#   display_name: "gotit_tureiyga_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "2be266c4-42d2-4e20-9069-d0084d78c567"
#     display_name: "slot-8"
#     value: "$slot-8"
#     entity_type_display_name: "@sys.email"
#     mandatory: true
#     prompts: "What Email?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/5a9841ee-21b8-42b4-a3ba-f6847e5b0ed0"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/5a9841ee-21b8-42b4-a3ba-f6847e5b0ed0"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/8c61eb9d-69a6-44ee-a73c-a3b9c070d5ce"
#   display_name: "gotit_dzlbcqek_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "a018843e-da05-48e3-a812-5642244df26b"
#     display_name: "slot-6"
#     value: "$slot-6"
#     entity_type_display_name: "@sys.person"
#     mandatory: true
#     prompts: "What Customer Name?"
#     is_list: true
#   }
#   parameters {
#     name: "962869d1-5d59-45c6-a68b-971c70a250a4"
#     display_name: "slot-7"
#     value: "$slot-7"
#     entity_type_display_name: "@sys.number"
#     mandatory: true
#     prompts: "What InDiE.slot.generic0002?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1, $result-slot-2, $result-slot-3"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/603bc34b-7a38-402c-a674-912d564e8c3c"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/603bc34b-7a38-402c-a674-912d564e8c3c"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/acf9e75e-fcee-472b-9654-177547fba5d4"
#   display_name: "gotit_zlfjkocp_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "6a358677-90b7-4be3-8772-db98decf6e63"
#     display_name: "slot-4"
#     value: "$slot-4"
#     entity_type_display_name: "@gotit-10"
#     mandatory: true
#     prompts: "What Promotion Name?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/e8db82e8-77f4-433a-a8bd-51ed7c44a7d7"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/e8db82e8-77f4-433a-a8bd-51ed7c44a7d7"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/445e223d-60b6-4f2a-887c-f79d019840c0"
#   display_name: "gotit_yrvqkgmw_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "26b96f3e-1db7-467f-860d-cfc78b688918"
#     display_name: "slot-3"
#     value: "$slot-3"
#     entity_type_display_name: "@sys.geo-city"
#     mandatory: true
#     prompts: "What City?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/a6f4ddef-82c5-4dfe-9b50-9b78324fe059"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/a6f4ddef-82c5-4dfe-9b50-9b78324fe059"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/6cc9b474-87e7-48ef-ae0c-285f746e6822"
#   display_name: "gotit_hubygliz_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "bf7d3efc-ce3e-4e2d-9024-d575e7610ebe"
#     display_name: "slot-3"
#     value: "$slot-3"
#     entity_type_display_name: "@sys.geo-city"
#     mandatory: true
#     prompts: "What City?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1, $result-slot-2"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/e96af4ac-89b2-4ea7-b467-6e68c7614b3d"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/e96af4ac-89b2-4ea7-b467-6e68c7614b3d"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/c86de71a-2dab-46f4-8599-5cdeca3965e1"
#   display_name: "gotit_edcuyjqa_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "a867399e-d386-4a27-8696-5431660a2367"
#     display_name: "slot-1"
#     value: "$slot-1"
#     entity_type_display_name: "@gotit-5"
#     mandatory: true
#     prompts: "What Product Name?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/40b74f47-8e5d-4545-b4cb-9c67ed10edf0"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/40b74f47-8e5d-4545-b4cb-9c67ed10edf0"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/19ebf0a3-1662-4355-bcf4-47e91ca95106"
#   display_name: "gotit_wlyokmra_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "47dc6d75-c83e-4979-9855-706559f9851d"
#     display_name: "slot-1"
#     value: "$slot-1"
#     entity_type_display_name: "@gotit-5"
#     mandatory: true
#     prompts: "What Product Name?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/72670a67-1be8-439b-9ee3-5bb5b44e021f"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/72670a67-1be8-439b-9ee3-5bb5b44e021f"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/47208ce6-8f38-4a4d-873e-998a84aaf682"
#   display_name: "gotit_rltvuehd_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "5761cf3c-9368-4f45-8ea4-8f2d775747ae"
#     display_name: "slot-1"
#     value: "$slot-1"
#     entity_type_display_name: "@gotit-5"
#     mandatory: true
#     prompts: "What Product Name?"
#     is_list: true
#   }
#   parameters {
#     name: "feb8069c-ed94-4885-a4e5-2c5f749dcaf3"
#     display_name: "slot-2"
#     value: "$slot-2"
#     entity_type_display_name: "@gotit-8"
#     mandatory: true
#     prompts: "What Product Category?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1, $result-slot-2, $result-slot-3, $result-slot-4, $result-slot-5"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/ee893cb1-ab02-4ce9-82e4-646dd1e79462"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/ee893cb1-ab02-4ce9-82e4-646dd1e79462"
# }
#
# Agent training:
