# %% [markdown]
# # InDiE DialogFlow publisher POC
#
# InDiE (Intent Discovery Engine) is a module that builds a tree of intents using supplied SQL queries and corresponding utterances. It also provides fulfillment logic to convert intent and slot values into a SQL query.
#
# ## DialogFlow publisher
# The DialogFlow (DF) publisher module takes the list of intents from a simplified InDiE json file. It uses DialogFlow APIs to create corresponding intents in a DialogFlow agent. It also configures DF agent to ask the user for any missing slots. Custom entities are also published so DF can detect particular types of entities from user utterance.

# %%
# %load_ext autoreload
# %autoreload 1

# !mkdir indie_df_publisher
# Out:
# mkdir: indie_df_publisher: File exists

# %%
# %%writefile indie_df_publisher/dialogflow_agent.py
import dialogflow_v2 as dialogflow

class DialogFlowAgent:
    def __init__(self, namespace, project):
        self.namespace = namespace
        self.project = project
        self.agents_client = dialogflow.AgentsClient()
        self.intents_client = dialogflow.IntentsClient()

        self.agent = self.load_agent()

    def load_agent(self):
        parent = self.agents_client.project_path(self.project)
        agent = self.agents_client.get_agent(parent)
        return agent

    def set_default_agent(self):
        parent = self.agents_client.project_path(self.project)

        a2 = dialogflow.types.Agent()
        a2.parent = parent
        a2.display_name = f"{self.namespace} agent"
        a2.default_language_code = "en"
        a2.time_zone = "America/Denver"
        a2.classification_threshold = 0.3
        self.agent = agents_client.set_agent(a2)
        return self.agent
    
    def list_intents(self):
        parent = self.intents_client.project_agent_path(self.project)
        return {x.display_name:x for x in self.intents_client.list_intents(parent)}

    def delete_indie_intents(self):
        parent = self.intents_client.project_agent_path(self.project)

        intents = self.list_intents()
        intents_to_delete = []
        for display_name in intents:
            if display_name.startswith(self.namespace):
                intents_to_delete.append(intents[display_name])
        if len(intents_to_delete) > 0:
            self.intents_client.batch_delete_intents(parent, intents_to_delete)
        
    def build_intent(self, display_name_suffix, training_phrases=None,
                      message_texts=None, parameters=None, is_fallback=False,
                      parent_followup_intent_name=None):
        parent = self.intents_client.project_agent_path(self.project)

        messages = []
        if message_texts:
            text = dialogflow.types.Intent.Message.Text(text=message_texts)
            message = dialogflow.types.Intent.Message(text=text)
            messages.append(message)

        intent = dialogflow.types.Intent(
            display_name=f"{self.namespace}_{display_name_suffix}",
            training_phrases=training_phrases,
            messages=messages,
            parameters=parameters,
            is_fallback=is_fallback,
            parent_followup_intent_name=parent_followup_intent_name)
        
        intent.webhook_state = dialogflow.types.Intent.WebhookState.WEBHOOK_STATE_ENABLED

        return intent

    def create_intents(self, intents):
        parent = self.intents_client.project_agent_path(self.project)

        intents_batch =  dialogflow.types.IntentBatch()
        intents_batch.intents.extend(intents)
        response = self.intents_client.batch_update_intents(parent, intent_batch_inline=intents_batch)

        def callback(operation_future):
            # Handle result.
            result = operation_future.result()
            print('Intents created:')
            print(result)

        response.add_done_callback(callback)
        
    def train(self):
        parent = self.agents_client.project_path(self.project)

        response = self.agents_client.train_agent(parent)
        def callback(operation_future):
            # Handle result.
            result = operation_future.result()
            print('Agent training:')
            print(result)

        response.add_done_callback(callback)
# Out:
# Overwriting indie_df_publisher/dialogflow_agent.py

# %%
# %%writefile indie_df_publisher/entity_types_publisher.py
import dialogflow_v2 as dialogflow

class EntityTypesPublisher:
    def __init__(self, namespace, project):
        self.client = dialogflow.EntityTypesClient()
        self.project = project
        self.namespace = namespace
        self.table_column_to_custom_entity = {}

    def create_entity_types(self, indie_custom_entities, indie):
        parent = self.client.project_agent_path(self.project)

        entity_type_batch = dialogflow.types.EntityTypeBatch()
        for de in indie_custom_entities:
            et = self.indie_custom_entity_to_dialogflow_entity_type(de)
            if et:
                entity_type_batch.entity_types.append(et)

        response = self.client.batch_update_entity_types(parent, entity_type_batch_inline=entity_type_batch)

        def callback(operation_future):
            # Handle result.
            result = operation_future.result()
            print('Entity types created')
            print(result)

        response.add_done_callback(callback)
        
    def indie_custom_entity_to_dialogflow_entity_type(self, indie_custom_entity):
        entity_type = dialogflow.types.EntityType()
        entity_type.display_name = f"{self.namespace}-{indie_custom_entity['index']}"
        self.table_column_to_custom_entity[f"{indie_custom_entity['table']}.{indie_custom_entity['column']}"] = f"@{entity_type.display_name}"
        entity_type.kind = 1
        
        for value, synonyms in indie_custom_entity['dictionary'].items():
            entity = dialogflow.types.EntityType.Entity()
            entity.value = value
            if len(synonyms) > 0:
                entity.synonyms.extend(synonyms)
            entity_type.entities.append(entity)
        
        return entity_type

    def list_entity_types(self):
        parent = self.client.project_agent_path(self.project)
        return {x.display_name:x for x in self.client.list_entity_types(parent)}
    
    def delete_indie_entity_types(self):
        parent = self.client.project_agent_path(self.project)

        entity_types = self.list_entity_types()
        entity_types_to_delete = []
        for display_name in entity_types:
            if display_name.startswith(self.namespace):
                entity_types_to_delete.append(entity_types[display_name].name)
        if len(entity_types_to_delete) > 0:
            self.client.batch_delete_entity_types(parent, entity_types_to_delete)
# Out:
# Overwriting indie_df_publisher/entity_types_publisher.py

# %%
# %%writefile indie_df_publisher/dialogflow_publisher.py

from indie_df_publisher.dialogflow_agent import DialogFlowAgent
from indie_df_publisher.entity_types_publisher import EntityTypesPublisher

import dialogflow_v2 as dialogflow

class DialogFlowPublisher:
    def __init__(self, namespace, project):
        self.namespace = namespace
        self.dialogflow_agent = DialogFlowAgent(namespace, project)
        self.entity_types_publisher = EntityTypesPublisher(namespace, project)
    
    def indie_training_phrases_to_dialogflow_training_phrases(self, indie_training_phrases):
        return [self.indie_training_phrase_to_dialogflow_training_phrase(tp) for tp in indie_training_phrases]
        
    def indie_training_phrase_to_dialogflow_training_phrase(self, indie_training_phrase):
        tp = dialogflow.types.Intent.TrainingPhrase()
        for part in indie_training_phrase['parts']:
            tpp = dialogflow.types.Intent.TrainingPhrase.Part()
            tpp.text = part['text']
            
            if 'alias' in part:
                tpp.alias = part['alias']

            if 'entity_type' in part:
                tpp.entity_type = part['entity_type']

            tp.parts.append(tpp)

        return tp    

    def indie_intent_to_dialogflow_intent(self, indie_intent, indie):
        display_name_suffix = indie_intent['id']

        training_phrases = self.indie_training_phrases_to_dialogflow_training_phrases(indie_intent['utterances'])
        followup_training_phrases = self.indie_training_phrases_to_dialogflow_training_phrases(indie_intent['followup_utterances'])

        parameters = []
        for indie_parameter in indie_intent['parameters']:
            parameter = dialogflow.types.Intent.Parameter(
                display_name=indie_parameter['id'],
                value=f"${indie_parameter['id']}",
                is_list=True,
                mandatory=indie_parameter['mandatory'],
                entity_type_display_name=indie_parameter['entity_type'],
                prompts=[f"What {indie_parameter['friendly_name']}?"])
            parameters.append(parameter)
            
        message = indie_intent['response_template']
        
        main_intent = self.dialogflow_agent.build_intent(display_name_suffix=display_name_suffix,
                                                  training_phrases=training_phrases,
                                                  message_texts=[message],
                                                  parameters=parameters,
                                                  is_fallback=False)

        followup_intent = self.dialogflow_agent.build_intent(display_name_suffix=display_name_suffix + '_followup',
                                                  training_phrases=followup_training_phrases,
                                                  message_texts=[message],
                                                  parameters=parameters,
                                                  is_fallback=False,
                                                  parent_followup_intent_name=main_intent.display_name)

        return main_intent, followup_intent
        

    def publish(self, indie):
        self.dialogflow_agent.delete_indie_intents()
        
        self.entity_types_publisher.delete_indie_entity_types()
        self.entity_types_publisher.create_entity_types(indie['custom_entities'].values(), indie)

        df_intents = []
        df_followup_intents = []
        indie_intents = indie['intents']
        
        for indie_intent in indie_intents:
            main_intent, followup_intent = self.indie_intent_to_dialogflow_intent(indie_intent, indie)
            df_intents.append(main_intent)
            if followup_intent:
                df_followup_intents.append(followup_intent)

        self.dialogflow_agent.create_intents(df_intents)
        intents = self.dialogflow_agent.list_intents()
        
        for df_followup_intent in df_followup_intents:
            df_followup_intent.parent_followup_intent_name = intents[df_followup_intent.parent_followup_intent_name].name

        self.dialogflow_agent.create_intents(df_followup_intents)
        
        self.dialogflow_agent.train()
# Out:
# Overwriting indie_df_publisher/dialogflow_publisher.py

# %%
# %%writefile indie_df_publisher/publish.py

# %aimport indie_df_publisher.dialogflow_agent
# %aimport indie_df_publisher.entity_types_publisher
# %aimport indie_df_publisher.dialogflow_publisher

from indie_df_publisher.dialogflow_publisher import DialogFlowPublisher

import dialogflow_v2 as dialogflow # https://dialogflow-python-client-v2.readthedocs.io/en/latest/gapic/v2beta1/api.html
import json

class args: pass

# Configuration to access and modify a DialogFlow agent
# %env GOOGLE_APPLICATION_CREDENTIALS=/Users/amolk/work/gotit/tutoruniverse/dialogflow_publisher/k3-oekhkw-65c192c69f18.json
args.dialogflow_project = "k3-oekhkw"
# args.simple_indie_format_file_path = "../data/InDiE_0.3_CCAI_20200608155202.simple.json"
args.simple_indie_format_file_path = "/Users/amolk/work/gotit/tutoruniverse/dialogflow_publisher/data/InDiE_0.3_Echo_20200612184151.simple.json"

publisher = DialogFlowPublisher(namespace='gotit', project=args.dialogflow_project)

with open(args.simple_indie_format_file_path) as json_file:
    simple_indie = json.load(json_file)

publisher.publish(simple_indie)
# Out:
# env: GOOGLE_APPLICATION_CREDENTIALS=/Users/amolk/work/gotit/tutoruniverse/dialogflow_publisher/k3-oekhkw-65c192c69f18.json
# Entity types created
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/775c2996-9abb-4b2a-90e2-0e9eeb239724"
#   display_name: "gotit-0"
#   kind: KIND_MAP
#   entities {
#     value: "online"
#     synonyms: "online"
#   }
#   entities {
#     value: "store"
#     synonyms: "store"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/8cc4cab4-a1da-48ee-b6d0-32fa18c0e334"
#   display_name: "gotit-1"
#   kind: KIND_MAP
#   entities {
#     value: "10GB plan"
#     synonyms: "10GB plan"
#   }
#   entities {
#     value: "earphones"
#     synonyms: "earphones"
#   }
#   entities {
#     value: "family plan"
#     synonyms: "family plan"
#   }
#   entities {
#     value: "ipad"
#     synonyms: "ipad"
#   }
#   entities {
#     value: "ipad pro"
#     synonyms: "ipad pro"
#   }
#   entities {
#     value: "iphone 11"
#     synonyms: "iphone 11"
#   }
#   entities {
#     value: "iphone 11 pro"
#     synonyms: "iphone 11 pro"
#   }
#   entities {
#     value: "iphone 7"
#     synonyms: "iphone 7"
#   }
#   entities {
#     value: "iphone 8"
#     synonyms: "iphone 8"
#   }
#   entities {
#     value: "iphone XS"
#     synonyms: "iphone XS"
#   }
#   entities {
#     value: "iphone cover"
#     synonyms: "iphone cover"
#   }
#   entities {
#     value: "screen protector"
#     synonyms: "screen protector"
#   }
#   entities {
#     value: "unlimited plan"
#     synonyms: "unlimited plan"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/29087c01-4059-4c37-b0f8-87b2aed3d7d2"
#   display_name: "gotit-2"
#   kind: KIND_MAP
#   entities {
#     value: "Email"
#     synonyms: "Email"
#   }
#   entities {
#     value: "SEM"
#     synonyms: "SEM"
#   }
#   entities {
#     value: "SEO"
#     synonyms: "SEO"
#   }
#   entities {
#     value: "SMS"
#     synonyms: "SMS"
#   }
#   entities {
#     value: "direct"
#     synonyms: "direct"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/6c722a58-1f58-4705-ab2e-58eb19585139"
#   display_name: "gotit-3"
#   kind: KIND_MAP
#   entities {
#     value: "Friday"
#     synonyms: "Friday"
#   }
#   entities {
#     value: "Monday"
#     synonyms: "Monday"
#   }
#   entities {
#     value: "Saturday"
#     synonyms: "Saturday"
#   }
#   entities {
#     value: "Sunday"
#     synonyms: "Sunday"
#   }
#   entities {
#     value: "Thursday"
#     synonyms: "Thursday"
#   }
#   entities {
#     value: "Tuesday"
#     synonyms: "Tuesday"
#   }
#   entities {
#     value: "Wednesday"
#     synonyms: "Wednesday"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/27445191-73dc-45c5-b488-08989e3f0d37"
#   display_name: "gotit-4"
#   kind: KIND_MAP
#   entities {
#     value: "April"
#     synonyms: "April"
#   }
#   entities {
#     value: "August"
#     synonyms: "August"
#   }
#   entities {
#     value: "December"
#     synonyms: "December"
#   }
#   entities {
#     value: "February"
#     synonyms: "February"
#   }
#   entities {
#     value: "January"
#     synonyms: "January"
#   }
#   entities {
#     value: "July"
#     synonyms: "July"
#   }
#   entities {
#     value: "June"
#     synonyms: "June"
#   }
#   entities {
#     value: "March"
#     synonyms: "March"
#   }
#   entities {
#     value: "May"
#     synonyms: "May"
#   }
#   entities {
#     value: "November"
#     synonyms: "November"
#   }
#   entities {
#     value: "October"
#     synonyms: "October"
#   }
#   entities {
#     value: "September"
#     synonyms: "September"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/408a87b1-e559-47f3-b3d7-f3feee1391df"
#   display_name: "gotit-5"
#   kind: KIND_MAP
#   entities {
#     value: "10GB plan"
#     synonyms: "10GB"
#     synonyms: "10GB plan"
#   }
#   entities {
#     value: "earphones"
#     synonyms: "earphones"
#   }
#   entities {
#     value: "family plan"
#     synonyms: "family plan"
#   }
#   entities {
#     value: "ipad"
#     synonyms: "iPads"
#     synonyms: "ipad"
#   }
#   entities {
#     value: "ipad pro"
#     synonyms: "ipad pro"
#   }
#   entities {
#     value: "iphone 11"
#     synonyms: "iphone 11"
#   }
#   entities {
#     value: "iphone 11 pro"
#     synonyms: "iphone 11 pro"
#   }
#   entities {
#     value: "iphone 7"
#     synonyms: "iphone 7"
#   }
#   entities {
#     value: "iphone 8"
#     synonyms: "iphone 8"
#   }
#   entities {
#     value: "iphone XS"
#     synonyms: "iphone XS"
#   }
#   entities {
#     value: "iphone cover"
#     synonyms: "iphone cover"
#   }
#   entities {
#     value: "screen protector"
#     synonyms: "screen protector"
#   }
#   entities {
#     value: "unlimited plan"
#     synonyms: "unlimited plan"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/beaab4c5-d915-4aa2-9a4d-92d91a0e386e"
#   display_name: "gotit-6"
#   kind: KIND_MAP
#   entities {
#     value: "10GB plan"
#     synonyms: "10GB plan"
#   }
#   entities {
#     value: "earphones"
#     synonyms: "earphones"
#   }
#   entities {
#     value: "family plan"
#     synonyms: "family plan"
#   }
#   entities {
#     value: "ipad"
#     synonyms: "ipad"
#   }
#   entities {
#     value: "ipad pro"
#     synonyms: "ipad pro"
#   }
#   entities {
#     value: "iphone 11"
#     synonyms: "iphone 11"
#   }
#   entities {
#     value: "iphone 11 pro"
#     synonyms: "iphone 11 pro"
#   }
#   entities {
#     value: "iphone 7"
#     synonyms: "iphone 7"
#   }
#   entities {
#     value: "iphone 8"
#     synonyms: "iphone 8"
#   }
#   entities {
#     value: "iphone XS"
#     synonyms: "iphone XS"
#   }
#   entities {
#     value: "iphone cover"
#     synonyms: "iphone cover"
#   }
#   entities {
#     value: "screen protector"
#     synonyms: "screen protector"
#   }
#   entities {
#     value: "unlimited plan"
#     synonyms: "unlimited plan"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/1448bee9-52ea-4e8c-832e-781bbab5c877"
#   display_name: "gotit-7"
#   kind: KIND_MAP
#   entities {
#     value: "accessories"
#     synonyms: "accessories"
#   }
#   entities {
#     value: "bundled plans"
#     synonyms: "bundled plans"
#   }
#   entities {
#     value: "phone"
#     synonyms: "phone"
#   }
#   entities {
#     value: "tablets"
#     synonyms: "tablets"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/4f240e22-626b-48c5-9973-bf730d112233"
#   display_name: "gotit-8"
#   kind: KIND_MAP
#   entities {
#     value: "devices"
#     synonyms: "devices"
#   }
#   entities {
#     value: "internet"
#     synonyms: "internet"
#   }
#   entities {
#     value: "voice plans"
#     synonyms: "voice plans"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/aa2c23d2-12df-4dac-a65a-d25074781a99"
#   display_name: "gotit-9"
#   kind: KIND_MAP
#   entities {
#     value: "black"
#     synonyms: "black"
#   }
#   entities {
#     value: "gold"
#     synonyms: "gold"
#   }
#   entities {
#     value: "red"
#     synonyms: "red"
#   }
#   entities {
#     value: "silver"
#     synonyms: "silver"
#   }
#   entities {
#     value: "white"
#     synonyms: "white"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/4aa0faa0-2c62-4eee-8df7-8e2e11b17578"
#   display_name: "gotit-10"
#   kind: KIND_MAP
#   entities {
#     value: "Black Friday"
#     synonyms: "Black Friday"
#   }
#   entities {
#     value: "Christmas"
#     synonyms: "Christmas"
#   }
#   entities {
#     value: "July 4"
#     synonyms: "July 4"
#   }
#   entities {
#     value: "Semi-annual"
#     synonyms: "Semi-annual"
#   }
#   entities {
#     value: "Valentine"
#     synonyms: "Valentine"
#   }
#   entities {
#     value: "Weekend"
#     synonyms: "Weekend"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/662edd4c-564a-4081-a8a6-0cf65e542e79"
#   display_name: "gotit-11"
#   kind: KIND_MAP
#   entities {
#     value: "buy_one_get_one"
#     synonyms: "buy_one_get_one"
#   }
#   entities {
#     value: "discount"
#     synonyms: "discount"
#   }
#   entities {
#     value: "multiples"
#     synonyms: "multiples"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/37536a4b-afd3-43b8-8fa4-0ff15c78775c"
#   display_name: "gotit-12"
#   kind: KIND_MAP
#   entities {
#     value: "billboard"
#     synonyms: "billboard"
#   }
#   entities {
#     value: "newspaper"
#     synonyms: "newspaper"
#   }
#   entities {
#     value: "pamphlet"
#     synonyms: "pamphlet"
#   }
#   entities {
#     value: "radio"
#     synonyms: "radio"
#   }
#   entities {
#     value: "tv"
#     synonyms: "tv"
#   }
#   entities {
#     value: "web"
#     synonyms: "web"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/d39fb95e-7290-4850-9355-d8daaab47423"
#   display_name: "gotit-13"
#   kind: KIND_MAP
#   entities {
#     value: "ABC"
#     synonyms: "ABC"
#   }
#   entities {
#     value: "CBS"
#     synonyms: "CBS"
#   }
#   entities {
#     value: "Facebook"
#     synonyms: "Facebook"
#   }
#   entities {
#     value: "Google ads"
#     synonyms: "Google ads"
#   }
#   entities {
#     value: "HBO"
#     synonyms: "HBO"
#   }
#   entities {
#     value: "LA time"
#     synonyms: "LA time"
#   }
#   entities {
#     value: "NY times"
#     synonyms: "NY times"
#   }
#   entities {
#     value: "Radio 92.3"
#     synonyms: "Radio 92.3"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/21f995ce-09cd-44b3-ae54-b8905a09ea60"
#   display_name: "gotit-14"
#   kind: KIND_MAP
#   entities {
#     value: "Atlanta"
#     synonyms: "Atlanta"
#   }
#   entities {
#     value: "Boston"
#     synonyms: "Boston"
#   }
#   entities {
#     value: "Cambridge"
#     synonyms: "Cambridge"
#   }
#   entities {
#     value: "Chicago"
#     synonyms: "Chicago"
#   }
#   entities {
#     value: "Kansas"
#     synonyms: "Kansas"
#   }
#   entities {
#     value: "Las Vegas"
#     synonyms: "Las Vegas"
#   }
#   entities {
#     value: "Los Angeles"
#     synonyms: "Los Angeles"
#   }
#   entities {
#     value: "Miami"
#     synonyms: "Miami"
#   }
#   entities {
#     value: "New York City"
#     synonyms: "New York City"
#   }
#   entities {
#     value: "San Francisco"
#     synonyms: "San Francisco"
#   }
#   entities {
#     value: "Seattle"
#     synonyms: "Seattle"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/b69566f5-70f2-4266-a0dc-451787a9a868"
#   display_name: "gotit-15"
#   kind: KIND_MAP
#   entities {
#     value: "online"
#     synonyms: "e-commerce"
#     synonyms: "online"
#   }
#   entities {
#     value: "physical"
#     synonyms: "physical"
#     synonyms: "store"
#   }
# }
# entity_types {
#   name: "projects/k3-oekhkw/agent/entityTypes/5c6a5423-3f05-4cf3-9e93-2115b692f046"
#   display_name: "gotit-16"
#   kind: KIND_MAP
#   entities {
#     value: "Midwest"
#     synonyms: "Midwest"
#   }
#   entities {
#     value: "Northeast"
#     synonyms: "Northeast"
#   }
#   entities {
#     value: "South"
#     synonyms: "South"
#   }
#   entities {
#     value: "West"
#     synonyms: "West"
#   }
# }
#
# Intents created:
# intents {
#   name: "projects/k3-oekhkw/agent/intents/d21bf224-d5f1-4627-857e-777bfc5fd8d8"
#   display_name: "gotit_atbijsoy"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "f5846de5-65cb-4e11-b97c-e772b8df2811"
#     display_name: "slot-8"
#     value: "$slot-8"
#     entity_type_display_name: "@sys.geo-state"
#     prompts: "What State?"
#     is_list: true
#   }
#   parameters {
#     name: "7e7584a3-9ed5-479a-997c-6d22a08701e2"
#     display_name: "slot-5"
#     value: "$slot-5"
#     entity_type_display_name: "@gotit-15"
#     mandatory: true
#     prompts: "What Store Type?"
#     is_list: true
#   }
#   parameters {
#     name: "573da0ba-3631-46e5-a8ef-e1cd29bb46aa"
#     display_name: "slot-6-7"
#     value: "$slot-6-7"
#     entity_type_display_name: "@sys.date-time"
#     prompts: "What Date?"
#     is_list: true
#   }
#   parameters {
#     name: "05acf199-d68d-4ba7-95dd-0161aab9aa13"
#     display_name: "slot-9"
#     value: "$slot-9"
#     entity_type_display_name: "@gotit-2"
#     prompts: "What Channel?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/9fe71ac7-4618-46c5-a50e-4714c04770ca"
#   display_name: "gotit_qpydahus"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "5f735e04-d8e9-4ae2-9862-72e99441e3aa"
#     display_name: "slot-3"
#     value: "$slot-3"
#     entity_type_display_name: "@gotit-9"
#     mandatory: true
#     prompts: "What Color?"
#     is_list: true
#   }
#   parameters {
#     name: "aaec5c97-b1f5-4251-8b51-052f033e51c8"
#     display_name: "slot-4"
#     value: "$slot-4"
#     entity_type_display_name: "@gotit-5"
#     mandatory: true
#     prompts: "What Product Name?"
#     is_list: true
#   }
#   parameters {
#     name: "fb28aa1b-76ef-4b5e-aef5-a3f9e44223de"
#     display_name: "slot-5"
#     value: "$slot-5"
#     entity_type_display_name: "@gotit-15"
#     mandatory: true
#     prompts: "What Store Type?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/62c3a1d2-aa57-4200-a49a-65672a721f67"
#   display_name: "gotit_asimzkwh"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "f8a39254-9ffe-41ce-945c-5831d048acaa"
#     display_name: "slot-2"
#     value: "$slot-2"
#     entity_type_display_name: "@sys.date-time"
#     mandatory: true
#     prompts: "What Date?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/41d05f62-658e-4cab-ae31-a2f7a6d7dcb4"
#   display_name: "gotit_xcujiltg"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "7a99e23c-ed93-4e81-a7a6-7253de32e0c1"
#     display_name: "slot-1"
#     value: "$slot-1"
#     entity_type_display_name: "@sys.number"
#     mandatory: true
#     prompts: "What Unit Cost?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1, $result-slot-2"
#     }
#   }
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/79e5f7e7-444e-4167-9335-6ddabb0a3aa7"
#   display_name: "gotit_bovjrswe"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
# }
#
# Intents created:
# intents {
#   name: "projects/k3-oekhkw/agent/intents/bcba34d1-ebba-463d-b31f-ac7254be3b5c"
#   display_name: "gotit_atbijsoy_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "37c72150-d7be-41d0-9cef-c3fa5fc6f3c8"
#     display_name: "slot-8"
#     value: "$slot-8"
#     entity_type_display_name: "@sys.geo-state"
#     prompts: "What State?"
#     is_list: true
#   }
#   parameters {
#     name: "c509d392-0bcf-4fdf-9567-fca258104e16"
#     display_name: "slot-5"
#     value: "$slot-5"
#     entity_type_display_name: "@gotit-15"
#     mandatory: true
#     prompts: "What Store Type?"
#     is_list: true
#   }
#   parameters {
#     name: "d1978210-6fae-4d06-b6d9-1727558167e5"
#     display_name: "slot-6-7"
#     value: "$slot-6-7"
#     entity_type_display_name: "@sys.date-time"
#     prompts: "What Date?"
#     is_list: true
#   }
#   parameters {
#     name: "f76167c1-8f9d-4431-9037-53bdbcfcdcbd"
#     display_name: "slot-9"
#     value: "$slot-9"
#     entity_type_display_name: "@gotit-2"
#     prompts: "What Channel?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/d21bf224-d5f1-4627-857e-777bfc5fd8d8"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/d21bf224-d5f1-4627-857e-777bfc5fd8d8"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/05013ed1-c882-465a-8149-aab8d95412d3"
#   display_name: "gotit_qpydahus_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "4fde83f7-9528-4406-a458-f85f7d074ec4"
#     display_name: "slot-3"
#     value: "$slot-3"
#     entity_type_display_name: "@gotit-9"
#     mandatory: true
#     prompts: "What Color?"
#     is_list: true
#   }
#   parameters {
#     name: "133fd742-92d7-485f-beae-0658f58a32f8"
#     display_name: "slot-4"
#     value: "$slot-4"
#     entity_type_display_name: "@gotit-5"
#     mandatory: true
#     prompts: "What Product Name?"
#     is_list: true
#   }
#   parameters {
#     name: "aa1d5525-e74f-48b2-98fa-deee8847471f"
#     display_name: "slot-5"
#     value: "$slot-5"
#     entity_type_display_name: "@gotit-15"
#     mandatory: true
#     prompts: "What Store Type?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/9fe71ac7-4618-46c5-a50e-4714c04770ca"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/9fe71ac7-4618-46c5-a50e-4714c04770ca"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/7322a095-870f-4268-9711-0016e2074915"
#   display_name: "gotit_asimzkwh_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "6b18a28f-e162-4ef2-9fac-cf96f606e3ac"
#     display_name: "slot-2"
#     value: "$slot-2"
#     entity_type_display_name: "@sys.date-time"
#     mandatory: true
#     prompts: "What Date?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/62c3a1d2-aa57-4200-a49a-65672a721f67"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/62c3a1d2-aa57-4200-a49a-65672a721f67"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/e47893d7-b078-4727-8fd3-4dbb042b2cbb"
#   display_name: "gotit_xcujiltg_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   parameters {
#     name: "9069621b-f717-4c50-a507-6b9a1145f63a"
#     display_name: "slot-1"
#     value: "$slot-1"
#     entity_type_display_name: "@sys.number"
#     mandatory: true
#     prompts: "What Unit Cost?"
#     is_list: true
#   }
#   messages {
#     text {
#       text: "Results: $result-slot-1, $result-slot-2"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/41d05f62-658e-4cab-ae31-a2f7a6d7dcb4"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/41d05f62-658e-4cab-ae31-a2f7a6d7dcb4"
# }
# intents {
#   name: "projects/k3-oekhkw/agent/intents/520c3a4f-bd07-4209-bd99-7a2aeff6d02c"
#   display_name: "gotit_bovjrswe_followup"
#   priority: 500000
#   webhook_state: WEBHOOK_STATE_ENABLED
#   messages {
#     text {
#       text: "Results: $result-slot-1"
#     }
#   }
#   root_followup_intent_name: "projects/k3-oekhkw/agent/intents/79e5f7e7-444e-4167-9335-6ddabb0a3aa7"
#   parent_followup_intent_name: "projects/k3-oekhkw/agent/intents/79e5f7e7-444e-4167-9335-6ddabb0a3aa7"
# }
#
# Agent training:
